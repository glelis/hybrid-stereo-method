# %% [markdown]
# ### Notebook criado para criar mascara em esferas

# %%
import cv2
import matplotlib.pyplot as plt
from photometric_stereo.psutil import criar_mascara_circulo_com_parametros, find_white_sphere
from photometric_stereo.psvizualization import plot_circle

# %%
# Load the image

PATH_IMG  = '/home/lelis/Documents/Projetos/hybrid-stereo-method/data/raw/photometric_stereo/ex23/images/image03.png'

image = cv2.imread(PATH_IMG, cv2.IMREAD_GRAYSCALE)

# %%
center, r  = find_white_sphere(image)
print(center)
plot_circle(image, center, r)
# Out:
# (np.int64(255), np.int64(229))

# %%
mascara = criar_mascara_circulo_com_parametros(center, r-1, image.shape)
plt.imshow(mascara, cmap='gray')

# %%
cv2.imwrite('/home/lelis/Documents/Projetos/hybrid-stereo-method/data/raw/photometric_stereo/ex23/mask.png', mascara)
# Out:
# True
