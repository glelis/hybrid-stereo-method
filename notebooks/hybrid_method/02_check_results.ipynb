# %%
from hybrid_stereo_method.infrastructure.visualization import display_image
from hybrid_stereo_method.infrastructure.io.image_io import read_fni_to_image_array, read_image, convert_image_array_to_fni
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
referencia = read_image('/home/lelis/Documents/Projetos/hybrid-stereo-method/data/raw/hybrid_stereo/2025-03-08-stQ-melon24-amb0.00-glo0.50/stQ-melon14-amb0.00-glo0.50/0512x0384-hs01-kr10/L000/sharp/hAvg.png')
convert_image_array_to_fni(referencia, '/home/lelis/Documents/Projetos/hybrid-stereo-method/data/raw/hybrid_stereo/2025-03-08-stQ-melon24-amb0.00-glo0.50/stQ-melon14-amb0.00-glo0.50/0512x0384-hs01-kr10/L000/sharp/hAvg.fni')

# %%
result_path = '/home/lelis/Documents/Projetos/hybrid-stereo-method/data/results/hybrid_stereo/20260330_1639_2025-03-08-stQ-melon24-amb0.00-glo0.50'

# %%
for i in range (0,7):
    image = f"height-0{i}-end-Z.fni"
    image_path = os.path.join(result_path, "integration", image)
    image = read_fni_to_image_array(image_path)
    #display_image(image=image, inline=True, colorbar=True)
    # Exibir a imagem
    #image = np.clip(image, np.percentile(image, 1), np.percentile(image, 99))  # Clip values to be in the range [0, 1]
    plt.imshow(image[:,:,0], cmap='gray')
    plt.colorbar()
    plt.title("Exibição da Imagem")
    plt.show()

# %%
result_path = '/home/lelis/Documents/Projetos/hybrid-stereo-method/csrc/integrate_recursive'

# %%
for i in range (0,8):
    image = f"teste_20260329-0{i}-beg-H.fni"
    image_path = os.path.join(result_path, image)
    image = read_fni_to_image_array(image_path)
    #display_image(image=image, inline=True, colorbar=True)
    # Exibir a imagem
    #image = np.clip(image, np.percentile(image, 1), np.percentile(image, 99))  # Clip values to be in the range [0, 1]
    plt.imshow(image[:,:,0], cmap='gray')
    plt.colorbar()
    plt.title("Exibição da Imagem")
    plt.show()
